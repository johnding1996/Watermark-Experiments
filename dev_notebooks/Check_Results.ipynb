# %%
import pandas as pd
from dev import *

df = pd.read_pickle("./all_result_v1.pkl")
df.head()
# Out:
#   eval_setup dataset_name source_name  \
# 0    removal       dalle3  stable_sig
# 1    removal       dalle3  stable_sig
# 2    removal       dalle3  stable_sig
# 3    removal       dalle3  stable_sig
# 4    removal       dalle3  stable_sig
#
#                                   attack_name  attack_strength   acc_1  \
# 0                             4x_regen_kl_vae              8.0  0.5001
# 1  adv_emb_clip_untg_alphaRatio_0.05_step_200              2.0  0.9984
# 2                                    2x_regen             20.0  0.5298
# 3                adv_cls_real_wm_0.01_50_warm              8.0  0.9980
# 4                adv_cls_real_wm_0.01_50_warm              6.0  0.9981
#
#       auc_1  low100_1  low1000_1                  legacy_fid  \
# 0  0.360216    0.0016     0.0004    (46.12348781608932, 0.0)
# 1  0.999695    0.9980     0.9972   (1.5416575532917705, 0.0)
# 2  0.537489    0.0098     0.0018    (4.808336591091461, 0.0)
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#      eval_setup dataset_name source_name  \
# 361     removal       dalle3   tree_ring
# 1046    removal       mscoco   tree_ring
# 1163   spoofing       dalle3  stable_sig
# 1165   spoofing       dalle3  stable_sig
# 1166   spoofing       dalle3  stable_sig
# ...         ...          ...         ...
# 3374   combined       mscoco   tree_ring
# 3375   combined       mscoco   tree_ring
# 3377   combined       mscoco   tree_ring
# 3378   combined       mscoco   tree_ring
# 3379   combined       mscoco   tree_ring
#
#                                      attack_name  attack_strength  acc_1  \
# 361                              regen_diffusion             20.0    NaN
# 1046                       adv_emb_resnet18_untg              8.0    NaN
# 1163                      adv_emb_klf16_vae_untg              2.0    NaN
# 1165  adv_emb_clip_untg_alphaRatio_0.05_step_200              4.0    NaN
# 1166  adv_emb_clip_untg_alphaRatio_0.05_step_200              2.0    NaN
# ...
